# %% [markdown]
# #                   ~ EDA CASE STUDY PROJECT ~

# %% [markdown]
# #### By MAANIK SHARMA

# %%
# Let Us import some  necessary libraries 
# Import the numpy, pandas, matplotlib, & seaborn packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1. Data Import and read

# %%
loan_data = pd.read_csv("/Users/maanik/Desktop/loan/loan.csv")
# Out:
# /var/folders/2x/1dgjy0_d6531lvb62gnxs4ww0000gn/T/ipykernel_18772/655793961.py:1: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   loan_data = pd.read_csv("/Users/maanik/Desktop/loan/loan.csv")

# %% [markdown]
# ## 2. Data Understanding

# %% [markdown]
# Read the loan data, inspect

# %%
#let us do some basic opertion in which we will able to understand given dataset

loan_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Columns: 111 entries, id to total_il_high_credit_limit
# dtypes: float64(74), int64(13), object(24)
# memory usage: 33.6+ MB

# %%
loan_data.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# 1   15.27%        59.83     C        C4  ...                NaN
# 2   15.96%        84.33     C        C5  ...                NaN
# 3   13.49%       339.31     C        C1  ...                NaN
# 4   12.69%        67.79     B        B5  ...                NaN
#
#   num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75 pub_rec_bankruptcies  \
# 0                NaN            NaN               NaN                  0.0
# 1                NaN            NaN               NaN                  0.0
# 2                NaN            NaN               NaN                  0.0
# 3                NaN            NaN               NaN                  0.0
# 4                NaN            NaN               NaN                  0.0
#
#   tax_liens tot_hi_cred_lim total_bal_ex_mort total_bc_limit  \
# 0       0.0             NaN               NaN            NaN
# 1       0.0             NaN               NaN            NaN
# 2       0.0             NaN               NaN            NaN
# 3       0.0             NaN               NaN            NaN
# 4       0.0             NaN               NaN            NaN
#
#   total_il_high_credit_limit
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
#
# [5 rows x 111 columns]

# %%
#no.of rows and columns of the dataframe
loan_data.shape
# Out:
# (39717, 111)

# %%
loan_data.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv   installment    annual_inc           dti  \
# count     39717.000000  39717.000000  3.971700e+04  39717.000000
# mean      10397.448868    324.561922  6.896893e+04     13.315130
# std        7128.450439    208.874874  6.379377e+04      6.678594
# min           0.000000     15.690000  4.000000e+03      0.000000
# 25%        5000.000000    167.020000  4.040400e+04      8.170000
# 50%        8975.000000    280.220000  5.900000e+04     13.400000
# 75%       14400.000000    430.780000  8.230000e+04     18.600000
# max       35000.000000   1305.190000  6.000000e+06     29.990000
#
#         delinq_2yrs  inq_last_6mths  ...  num_tl_90g_dpd_24m  \
# count  39717.000000    39717.000000  ...                 0.0
# mean       0.146512        0.869200  ...                 NaN
# std        0.491812        1.070219  ...                 NaN
# min        0.000000        0.000000  ...                 NaN
# 25%        0.000000        0.000000  ...                 NaN
# 50%        0.000000        1.000000  ...                 NaN
# 75%        0.000000        1.000000  ...                 NaN
# max       11.000000        8.000000  ...                 NaN
#
#        num_tl_op_past_12m  pct_tl_nvr_dlq  percent_bc_gt_75  \
# count                 0.0             0.0               0.0
# mean                  NaN             NaN               NaN
# std                   NaN             NaN               NaN
# min                   NaN             NaN               NaN
# 25%                   NaN             NaN               NaN
# 50%                   NaN             NaN               NaN
# 75%                   NaN             NaN               NaN
# max                   NaN             NaN               NaN
#
#        pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  total_bal_ex_mort  \
# count          39020.000000    39678.0              0.0                0.0
# mean               0.043260        0.0              NaN                NaN
# std                0.204324        0.0              NaN                NaN
# min                0.000000        0.0              NaN                NaN
# 25%                0.000000        0.0              NaN                NaN
# 50%                0.000000        0.0              NaN                NaN
# 75%                0.000000        0.0              NaN                NaN
# max                2.000000        0.0              NaN                NaN
#
#        total_bc_limit  total_il_high_credit_limit
# count             0.0                         0.0
# mean              NaN                         NaN
# std               NaN                         NaN
# min               NaN                         NaN
# 25%               NaN                         NaN
# 50%               NaN                         NaN
# 75%               NaN                         NaN
# max               NaN                         NaN
#
# [8 rows x 87 columns]

# %%
# Looking at all the column names
loan_data.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'pct_tl_nvr_dlq',
#        'percent_bc_gt_75', 'pub_rec_bankruptcies', 'tax_liens',
#        'tot_hi_cred_lim', 'total_bal_ex_mort', 'total_bc_limit',
#        'total_il_high_credit_limit'],
#       dtype='object', length=111)

# %% [markdown]
# ## 3. Data Cleaning

# %% [markdown]
# clean and prepare the data..

# %%
# As we seen in previous operation there are many infomation ,null values which is not required.
#Let us clean the dataset.

loan_data.isnull().sum()
# Out:
# id                                0
# member_id                         0
# loan_amnt                         0
# funded_amnt                       0
# funded_amnt_inv                   0
#                               ...
# tax_liens                        39
# tot_hi_cred_lim               39717
# total_bal_ex_mort             39717
# total_bc_limit                39717
# total_il_high_credit_limit    39717
# Length: 111, dtype: int64

# %%
# percentage of missing values in each column
round(loan_data.isnull().sum()/len(loan_data.index), 2)*100
# Out:
# id                              0.0
# member_id                       0.0
# loan_amnt                       0.0
# funded_amnt                     0.0
# funded_amnt_inv                 0.0
#                               ...
# tax_liens                       0.0
# tot_hi_cred_lim               100.0
# total_bal_ex_mort             100.0
# total_bc_limit                100.0
# total_il_high_credit_limit    100.0
# Length: 111, dtype: float64

# %%
missing_columns = loan_data.columns[loan_data.isnull().mean() > 0.9].tolist()
print(f'Removing columns with >90% missing values: {missing_columns}')
# Out:
# Removing columns with >90% missing values: ['mths_since_last_record', 'next_pymnt_d', 'mths_since_last_major_derog', 'annual_inc_joint', 'dti_joint', 'verification_status_joint', 'tot_coll_amt', 'tot_cur_bal', 'open_acc_6m', 'open_il_6m', 'open_il_12m', 'open_il_24m', 'mths_since_rcnt_il', 'total_bal_il', 'il_util', 'open_rv_12m', 'open_rv_24m', 'max_bal_bc', 'all_util', 'total_rev_hi_lim', 'inq_fi', 'total_cu_tl', 'inq_last_12m', 'acc_open_past_24mths', 'avg_cur_bal', 'bc_open_to_buy', 'bc_util', 'mo_sin_old_il_acct', 'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl', 'mort_acc', 'mths_since_recent_bc', 'mths_since_recent_bc_dlq', 'mths_since_recent_inq', 'mths_since_recent_revol_delinq', 'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_actv_rev_tl', 'num_bc_sats', 'num_bc_tl', 'num_il_tl', 'num_op_rev_tl', 'num_rev_accts', 'num_rev_tl_bal_gt_0', 'num_sats', 'num_tl_120dpd_2m', 'num_tl_30dpd', 'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'pct_tl_nvr_dlq', 'percent_bc_gt_75', 'tot_hi_cred_lim', 'total_bal_ex_mort', 'total_bc_limit', 'total_il_high_credit_limit']

# %%
#droping them
loan = loan_data.drop(missing_columns, axis=1)

# Checking shape again
print(loan.shape)
# Out:
# (39717, 55)

# %%
#Checking null values percentage again.
100*(loan.isnull().sum()/len(loan.index))
# Out:
# id                             0.000000
# member_id                      0.000000
# loan_amnt                      0.000000
# funded_amnt                    0.000000
# funded_amnt_inv                0.000000
# term                           0.000000
# int_rate                       0.000000
# installment                    0.000000
# grade                          0.000000
# sub_grade                      0.000000
# emp_title                      6.191303
# emp_length                     2.706650
# home_ownership                 0.000000
# annual_inc                     0.000000
# verification_status            0.000000
# issue_d                        0.000000
# loan_status                    0.000000
# pymnt_plan                     0.000000
# url                            0.000000
# desc                          32.585543
# purpose                        0.000000
# title                          0.027696
# zip_code                       0.000000
# addr_state                     0.000000
# dti                            0.000000
# delinq_2yrs                    0.000000
# earliest_cr_line               0.000000
# inq_last_6mths                 0.000000
# mths_since_last_delinq        64.662487
# open_acc                       0.000000
# pub_rec                        0.000000
# revol_bal                      0.000000
# revol_util                     0.125891
# total_acc                      0.000000
# initial_list_status            0.000000
# out_prncp                      0.000000
# out_prncp_inv                  0.000000
# total_pymnt                    0.000000
# total_pymnt_inv                0.000000
# total_rec_prncp                0.000000
# total_rec_int                  0.000000
# total_rec_late_fee             0.000000
# recoveries                     0.000000
# collection_recovery_fee        0.000000
# last_pymnt_d                   0.178765
# last_pymnt_amnt                0.000000
# last_credit_pull_d             0.005036
# collections_12_mths_ex_med     0.140998
# policy_code                    0.000000
# application_type               0.000000
# acc_now_delinq                 0.000000
# chargeoff_within_12_mths       0.140998
# delinq_amnt                    0.000000
# pub_rec_bankruptcies           1.754916
# tax_liens                      0.098195
# dtype: float64

# %%
# There are now 2 columns having approx 32 and 64% missing values -
# description and months since last delinquent
# Looking at few enteries in columns
loan[['desc', 'mths_since_last_delinq']].head()
# Out:
#                                                 desc  mths_since_last_delinq
# 0    Borrower added on 12/22/11 > I need to upgra...                     NaN
# 1    Borrower added on 12/22/11 > I plan to use t...                     NaN
# 2                                                NaN                     NaN
# 3    Borrower added on 12/21/11 > to pay for prop...                    35.0
# 4    Borrower added on 12/21/11 > I plan on combi...                    38.0

# %%
#now dropping some other columns with high percentage of null values. i.e 32 and 64 percetage.
# Dropping the two columns as it is irrelavent for our analysis.
loan = loan.drop(['desc', 'mths_since_last_delinq'], axis=1)

# %%
# Checking percentage null value again.
100*(loan.isnull().sum()/len(loan.index))
# Out:
# id                            0.000000
# member_id                     0.000000
# loan_amnt                     0.000000
# funded_amnt                   0.000000
# funded_amnt_inv               0.000000
# term                          0.000000
# int_rate                      0.000000
# installment                   0.000000
# grade                         0.000000
# sub_grade                     0.000000
# emp_title                     6.191303
# emp_length                    2.706650
# home_ownership                0.000000
# annual_inc                    0.000000
# verification_status           0.000000
# issue_d                       0.000000
# loan_status                   0.000000
# pymnt_plan                    0.000000
# url                           0.000000
# purpose                       0.000000
# title                         0.027696
# zip_code                      0.000000
# addr_state                    0.000000
# dti                           0.000000
# delinq_2yrs                   0.000000
# earliest_cr_line              0.000000
# inq_last_6mths                0.000000
# open_acc                      0.000000
# pub_rec                       0.000000
# revol_bal                     0.000000
# revol_util                    0.125891
# total_acc                     0.000000
# initial_list_status           0.000000
# out_prncp                     0.000000
# out_prncp_inv                 0.000000
# total_pymnt                   0.000000
# total_pymnt_inv               0.000000
# total_rec_prncp               0.000000
# total_rec_int                 0.000000
# total_rec_late_fee            0.000000
# recoveries                    0.000000
# collection_recovery_fee       0.000000
# last_pymnt_d                  0.178765
# last_pymnt_amnt               0.000000
# last_credit_pull_d            0.005036
# collections_12_mths_ex_med    0.140998
# policy_code                   0.000000
# application_type              0.000000
# acc_now_delinq                0.000000
# chargeoff_within_12_mths      0.140998
# delinq_amnt                   0.000000
# pub_rec_bankruptcies          1.754916
# tax_liens                     0.098195
# dtype: float64

# %%
# Checking missing values in rows
loan.isnull().sum(axis=1)
# Out:
# 0        1
# 1        0
# 2        1
# 3        0
# 4        0
#         ..
# 39712    4
# 39713    4
# 39714    5
# 39715    5
# 39716    4
# Length: 39717, dtype: int64

# %%
# Checking whether some rows have more than 5 missing values
len(loan[loan.isnull().sum(axis=1) > 5].index)
# Out:
# 0

# %%
# analysing unique values in each column 
loan.apply(pd.Series.nunique)
# Out:
# id                            39717
# member_id                     39717
# loan_amnt                       885
# funded_amnt                    1041
# funded_amnt_inv                8205
# term                              2
# int_rate                        371
# installment                   15383
# grade                             7
# sub_grade                        35
# emp_title                     28820
# emp_length                       11
# home_ownership                    5
# annual_inc                     5318
# verification_status               3
# issue_d                          55
# loan_status                       3
# pymnt_plan                        1
# url                           39717
# purpose                          14
# title                         19615
# zip_code                        823
# addr_state                       50
# dti                            2868
# delinq_2yrs                      11
# earliest_cr_line                526
# inq_last_6mths                    9
# open_acc                         40
# pub_rec                           5
# revol_bal                     21711
# revol_util                     1089
# total_acc                        82
# initial_list_status               1
# out_prncp                      1137
# out_prncp_inv                  1138
# total_pymnt                   37850
# total_pymnt_inv               37518
# total_rec_prncp                7976
# total_rec_int                 35148
# total_rec_late_fee             1356
# recoveries                     4040
# collection_recovery_fee        2616
# last_pymnt_d                    101
# last_pymnt_amnt               34930
# last_credit_pull_d              106
# collections_12_mths_ex_med        1
# policy_code                       1
# application_type                  1
# acc_now_delinq                    1
# chargeoff_within_12_mths          1
# delinq_amnt                       1
# pub_rec_bankruptcies              3
# tax_liens                         1
# dtype: int64

# %%
#deleting columns with only 1 unique value because its not required for analysis.
loan=loan.loc[:,loan.nunique()!=1]

# %%
#Checking the shape again
loan.shape
# Out:
# (39717, 44)

# %%
# Now Checking the datatype 
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 44 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       39717 non-null  int64
#  1   member_id                39717 non-null  int64
#  2   loan_amnt                39717 non-null  int64
#  3   funded_amnt              39717 non-null  int64
#  4   funded_amnt_inv          39717 non-null  float64
#  5   term                     39717 non-null  object
#  6   int_rate                 39717 non-null  object
#  7   installment              39717 non-null  float64
#  8   grade                    39717 non-null  object
#  9   sub_grade                39717 non-null  object
#  10  emp_title                37258 non-null  object
#  11  emp_length               38642 non-null  object
#  12  home_ownership           39717 non-null  object
#  13  annual_inc               39717 non-null  float64
#  14  verification_status      39717 non-null  object
#  15  issue_d                  39717 non-null  object
#  16  loan_status              39717 non-null  object
#  17  url                      39717 non-null  object
#  18  purpose                  39717 non-null  object
#  19  title                    39706 non-null  object
#  20  zip_code                 39717 non-null  object
#  21  addr_state               39717 non-null  object
#  22  dti                      39717 non-null  float64
#  23  delinq_2yrs              39717 non-null  int64
#  24  earliest_cr_line         39717 non-null  object
#  25  inq_last_6mths           39717 non-null  int64
#  26  open_acc                 39717 non-null  int64
#  27  pub_rec                  39717 non-null  int64
#  28  revol_bal                39717 non-null  int64
#  29  revol_util               39667 non-null  object
#  30  total_acc                39717 non-null  int64
#  31  out_prncp                39717 non-null  float64
#  32  out_prncp_inv            39717 non-null  float64
#  33  total_pymnt              39717 non-null  float64
#  34  total_pymnt_inv          39717 non-null  float64
#  35  total_rec_prncp          39717 non-null  float64
#  36  total_rec_int            39717 non-null  float64
#  37  total_rec_late_fee       39717 non-null  float64
#  38  recoveries               39717 non-null  float64
#  39  collection_recovery_fee  39717 non-null  float64
#  40  last_pymnt_d             39646 non-null  object
#  41  last_pymnt_amnt          39717 non-null  float64
#  42  last_credit_pull_d       39715 non-null  object
#  43  pub_rec_bankruptcies     39020 non-null  float64
# dtypes: float64(15), int64(10), object(19)
# memory usage: 13.3+ MB

# %%
# The column int_rate is character type, converting it to float
loan['int_rate'] = loan['int_rate'].apply(lambda x: x.split("%")[0])           
loan['int_rate'] = loan['int_rate'].astype(float)

# %%
# Checking the data types again
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 44 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       39717 non-null  int64
#  1   member_id                39717 non-null  int64
#  2   loan_amnt                39717 non-null  int64
#  3   funded_amnt              39717 non-null  int64
#  4   funded_amnt_inv          39717 non-null  float64
#  5   term                     39717 non-null  object
#  6   int_rate                 39717 non-null  float64
#  7   installment              39717 non-null  float64
#  8   grade                    39717 non-null  object
#  9   sub_grade                39717 non-null  object
#  10  emp_title                37258 non-null  object
#  11  emp_length               38642 non-null  object
#  12  home_ownership           39717 non-null  object
#  13  annual_inc               39717 non-null  float64
#  14  verification_status      39717 non-null  object
#  15  issue_d                  39717 non-null  object
#  16  loan_status              39717 non-null  object
#  17  url                      39717 non-null  object
#  18  purpose                  39717 non-null  object
#  19  title                    39706 non-null  object
#  20  zip_code                 39717 non-null  object
#  21  addr_state               39717 non-null  object
#  22  dti                      39717 non-null  float64
#  23  delinq_2yrs              39717 non-null  int64
#  24  earliest_cr_line         39717 non-null  object
#  25  inq_last_6mths           39717 non-null  int64
#  26  open_acc                 39717 non-null  int64
#  27  pub_rec                  39717 non-null  int64
#  28  revol_bal                39717 non-null  int64
#  29  revol_util               39667 non-null  object
#  30  total_acc                39717 non-null  int64
#  31  out_prncp                39717 non-null  float64
#  32  out_prncp_inv            39717 non-null  float64
#  33  total_pymnt              39717 non-null  float64
#  34  total_pymnt_inv          39717 non-null  float64
#  35  total_rec_prncp          39717 non-null  float64
#  36  total_rec_int            39717 non-null  float64
#  37  total_rec_late_fee       39717 non-null  float64
#  38  recoveries               39717 non-null  float64
#  39  collection_recovery_fee  39717 non-null  float64
#  40  last_pymnt_d             39646 non-null  object
#  41  last_pymnt_amnt          39717 non-null  float64
#  42  last_credit_pull_d       39715 non-null  object
#  43  pub_rec_bankruptcies     39020 non-null  float64
# dtypes: float64(16), int64(10), object(18)
# memory usage: 13.3+ MB

# %%
# Extracting the numeric part from the variable employment length

# Droping the missing values from the column 
loan = loan[~loan['emp_length'].isnull()]

# writing a function numeric that will return digits from given string.

def numeric(n):
    string = ""
    for word in n:
        if word.isdigit():
            string = string + word
    return string

# Using numeric function to extract numeric values from the string
loan['emp_length'] = loan['emp_length'].apply(lambda x: numeric(x))

# converting to integer datatype
loan['emp_length'] = loan['emp_length'].astype('int64')

# %% [markdown]
# ##  4.Data Analysis

# %%
# To do Data Analysis we have to remove some columns which are not required
extra_columns = [
  "delinq_2yrs",
  "earliest_cr_line",
  "inq_last_6mths",
  "open_acc",
  "pub_rec",
  "revol_bal",
  "revol_util",
  "total_acc",
  "out_prncp",
  "out_prncp_inv",
  "total_pymnt",
  "total_pymnt_inv",
  "total_rec_prncp",
  "total_rec_int",
  "total_rec_late_fee",
  "recoveries",
  "collection_recovery_fee",
  "last_pymnt_d",
  "last_pymnt_amnt",
  "last_credit_pull_d"]

# %%
# let's now remove the extra columns from analysis
df = loan.drop(extra_columns, axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 38642 entries, 0 to 39716
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    38642 non-null  int64
#  1   member_id             38642 non-null  int64
#  2   loan_amnt             38642 non-null  int64
#  3   funded_amnt           38642 non-null  int64
#  4   funded_amnt_inv       38642 non-null  float64
#  5   term                  38642 non-null  object
#  6   int_rate              38642 non-null  float64
#  7   installment           38642 non-null  float64
#  8   grade                 38642 non-null  object
#  9   sub_grade             38642 non-null  object
#  10  emp_title             37202 non-null  object
#  11  emp_length            38642 non-null  int64
#  12  home_ownership        38642 non-null  object
#  13  annual_inc            38642 non-null  float64
#  14  verification_status   38642 non-null  object
#  15  issue_d               38642 non-null  object
#  16  loan_status           38642 non-null  object
#  17  url                   38642 non-null  object
#  18  purpose               38642 non-null  object
#  19  title                 38632 non-null  object
#  20  zip_code              38642 non-null  object
#  21  addr_state            38642 non-null  object
#  22  dti                   38642 non-null  float64
#  23  pub_rec_bankruptcies  37945 non-null  float64
# dtypes: float64(6), int64(5), object(13)
# memory usage: 7.4+ MB

# %%
# we will not be able to use the variables zip code, address, state etc.
# the variable 'title' is derived from the variable 'purpose'
# thus let get rid of all these variables as well

df = df.drop(['title', 'url', 'zip_code', 'addr_state'], axis=1)

# %%
#check loan status
df['loan_status'] = df['loan_status'].astype('category')
df['loan_status'].value_counts()
# Out:
# loan_status
# Fully Paid     32145
# Charged Off     5399
# Current         1098
# Name: count, dtype: int64

# %%
# filtering only fully paid or charged-off
df = df[df['loan_status'] != 'Current']
df['loan_status'] = df['loan_status'].apply(lambda x: 0 if x=='Fully Paid' else 1)

# converting loan_status to integer type
df['loan_status'] = df['loan_status'].apply(lambda x: pd.to_numeric(x))

# summarising the values
df['loan_status'].value_counts()
# Out:
# loan_status
# 0    32145
# 1     5399
# Name: count, dtype: int64

# %%
# create a new column for loan to income ratio

loan['loan_inc_ratio']= 100*(loan['loan_amnt']/loan['annual_inc'])
loan.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#    int_rate  installment grade sub_grade  ... total_rec_prncp  total_rec_int  \
# 0     10.65       162.87     B        B2  ...         5000.00         863.16
# 1     15.27        59.83     C        C4  ...          456.46         435.17
# 2     15.96        84.33     C        C5  ...         2400.00         605.67
# 3     13.49       339.31     C        C1  ...        10000.00        2214.92
# 4     12.69        67.79     B        B5  ...         2475.94        1037.39
#
#   total_rec_late_fee  recoveries collection_recovery_fee last_pymnt_d  \
# 0               0.00        0.00                    0.00       Jan-15
# 1               0.00      117.08                    1.11       Apr-13
# 2               0.00        0.00                    0.00       Jun-14
# 3              16.97        0.00                    0.00       Jan-15
# 4               0.00        0.00                    0.00       May-16
#
#   last_pymnt_amnt last_credit_pull_d pub_rec_bankruptcies loan_inc_ratio
# 0          171.62             May-16                  0.0      20.833333
# 1          119.66             Sep-13                  0.0       8.333333
# 2          649.91             May-16                  0.0      19.588639
# 3          357.48             Apr-16                  0.0      20.325203
# 4           67.79             May-16                  0.0       3.750000
#
# [5 rows x 45 columns]

# %%
# Extract Year and month from Issue_Date to separate columns
# Using expand=True to directly create two new columns from the split parts
loan[['issue_month', 'issue_year']] = loan['issue_d'].str.split('-', expand=True)

loan['issue_year'] = '20' + loan['issue_year'].astype(str) # Ensure it's string before concatenation

# Display the head of the DataFrame to see the changes
loan.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#    int_rate  installment grade sub_grade  ... total_rec_late_fee  recoveries  \
# 0     10.65       162.87     B        B2  ...               0.00        0.00
# 1     15.27        59.83     C        C4  ...               0.00      117.08
# 2     15.96        84.33     C        C5  ...               0.00        0.00
# 3     13.49       339.31     C        C1  ...              16.97        0.00
# 4     12.69        67.79     B        B5  ...               0.00        0.00
#
#   collection_recovery_fee  last_pymnt_d last_pymnt_amnt last_credit_pull_d  \
# 0                    0.00        Jan-15          171.62             May-16
# 1                    1.11        Apr-13          119.66             Sep-13
# 2                    0.00        Jun-14          649.91             May-16
# 3                    0.00        Jan-15          357.48             Apr-16
# 4                    0.00        May-16           67.79             May-16
#
#   pub_rec_bankruptcies loan_inc_ratio issue_month issue_year
# 0                  0.0      20.833333         Dec       2011
# 1                  0.0       8.333333         Dec       2011
# 2                  0.0      19.588639         Dec       2011
# 3                  0.0      20.325203         Dec       2011
# 4                  0.0       3.750000         Dec       2011
#
# [5 rows x 47 columns]

# %%
# Get the 25%, 50% and 75% quartiles of the loan_inc_ratio column for categorisation

loan['loan_inc_ratio'].quantile([.25, .5, .75])
# Out:
# 0.25     9.983330
# 0.50    16.483516
# 0.75    25.000000
# Name: loan_inc_ratio, dtype: float64

# %%
# Checking default rate
# Map loan_status to binary: Fully Paid = 0, Charged Off = 1
df['default'] = df['loan_status'].apply(lambda x: 1 if x == 'Charged Off' else 0)
round(df['default'].mean() * 100, 2)
# Out:
# 0.0

# %%
def plot_category(var):
    temp = df.groupby(var)['default'].mean().sort_values(ascending=False)
    sns.barplot(x=temp.index, y=temp.values)
    plt.ylabel('Default Rate')
    plt.xticks(rotation=45)
    plt.title(f'Default Rate by {var}')
    plt.show()

# %%
# Defining a function to plot default rate across categorical variables for futher use.
def plot_category(var):
    sns.barplot(x=var, y='loan_status', data=df)
    plt.title("Default Rates Across " + var.title())
    plt.show()

# %%
# Comparing default rates across grade of loan
plot_category('grade')

# %% [markdown]
# Clearly, as the grade of loan goes from A to G, the default rate increases. This is expected because the grade is decided by Lending Club based on the riskiness of the loan.

# %%
# Ploting default rates across term 
plot_category('term')

# %%
# subgrades across default rate
plt.figure(figsize=(16, 6))
plot_category('sub_grade')

# %%
# plotting  home ownership 
plot_category('home_ownership')

# %%
# verification_status: surprisingly, verified loans default more than not verifiedb
plot_category('verification_status')

# %% [markdown]
# As we can see verified loans have more default rate as compared to other.

# %%
# ploting purpose of loans across default rate.
plt.figure(figsize=(16, 6))
plt.xticks(rotation=90)
plot_category('purpose')

# %%
# let's also observe the distribution of loans across years
# first lets convert the year column into datetime and then extract year and month from it
df['issue_d'].head()
# Out:
# 0    Dec-11
# 1    Dec-11
# 2    Dec-11
# 3    Dec-11
# 5    Dec-11
# Name: issue_d, dtype: object

# %%
# converting issue date to datetime format.
from datetime import datetime
df['issue_d'] = df['issue_d'].apply(lambda x: datetime.strptime(x, '%b-%y'))
df['issue_d']
# Out:
# 0       2011-12-01
# 1       2011-12-01
# 2       2011-12-01
# 3       2011-12-01
# 5       2011-12-01
#            ...
# 39712   2007-07-01
# 39713   2007-07-01
# 39714   2007-07-01
# 39715   2007-07-01
# 39716   2007-06-01
# Name: issue_d, Length: 37544, dtype: datetime64[ns]

# %%
# extracting month and year from issue_date
df['month'] = df['issue_d'].apply(lambda x: x.month)
df['year'] = df['issue_d'].apply(lambda x: x.year)

# %%
# let's first observe the number of loans granted across years
df.groupby('year').year.count()
# Out:
# year
# 2007      251
# 2008     1562
# 2009     4716
# 2010    11214
# 2011    19801
# Name: year, dtype: int64

# %% [markdown]
# As expected we can observe when we are increasing no. of years the no of loans are also increasing.

# %%
# let us see with month too...
df.groupby('month').month.count()
# Out:
# month
# 1     2331
# 2     2278
# 3     2632
# 4     2756
# 5     2838
# 6     3094
# 7     3253
# 8     3321
# 9     3394
# 10    3637
# 11    3890
# 12    4120
# Name: month, dtype: int64

# %%
# lets compare the default rates across years
plot_category('year')

# %%
# comparing default rates across months too 
plt.figure(figsize=(16, 6))
plot_category('month')

# %%
sns.histplot(df['loan_amnt'], kde=True, bins=30)
plt.title('Distribution of Loan Amounts')
plt.xlabel('Loan Amount')
plt.ylabel('Frequency')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# let us make a category to better understand
def loan_amount(n):
    if n < 5000:
        return 'low'
    elif n >=5000 and n < 15000:
        return 'medium'
    elif n >= 15000 and n < 25000:
        return 'high'
    else:
        return 'very high'
        
df['loan_amnt'] = df['loan_amnt'].apply(lambda x: loan_amount(x))

# %%
df['loan_amnt'].value_counts()
# Out:
# loan_amnt
# medium       20157
# high          7572
# low           7095
# very high     2720
# Name: count, dtype: int64

# %%
# ploting category wise
plot_category('loan_amnt')

# %%
# let's also convert funded amount into category wise
df['funded_amnt_inv'] = df['funded_amnt_inv'].apply(lambda x: loan_amount(x))

# %%
# ploting funded amount into category wise
plot_category('funded_amnt_inv')

# %% [markdown]
# From last 2 plot we can see that the as default rate increase the amount and funded amount increases.

# %%
# lets also convert interest rate to low, medium, high

def int_rate(n):
    if n <= 10:
        return 'low'
    elif n > 10 and n <=15:
        return 'medium'
    else:
        return 'high'
    
    
df['int_rate'] = df['int_rate'].apply(lambda x: int_rate(x))

# %%
# ploting default rates across rates of interest
plot_category('int_rate')

# %% [markdown]
# As expected the higher default rate has higher interst on it.

# %%
# debt to income ratio
def dti(n):
    if n <= 10:
        return 'low'
    elif n > 10 and n <=20:
        return 'medium'
    else:
        return 'high'
    

df['dti'] = df['dti'].apply(lambda x: dti(x))

# %%
# ploting default rates across debt to income ratio
plot_category('dti')

# %%
plot_category('dti')

# This ensures that all values in the column are numbers or NaN before comparison.
df['funded_amnt'] = pd.to_numeric(df['funded_amnt'], errors='coerce')

# categorizing funded amount
def funded_amount(n):
    # It's a good practice to handle potential NaN values after coercion
    if pd.isna(n):
        return 'unknown_category' # Or 'N/A', 'Missing', etc., choose what makes sense
    elif n <= 5000:
        return 'low'
    elif n > 5000 and n <= 15000:
        return 'medium'
    else:
        return 'high'


df['funded_amnt'] = df['funded_amnt'].apply(lambda x: funded_amount(x))

# %%
#ploting default rates across funded amount
plot_category('funded_amnt')

# %%
# Categorizing installment
def installment(n):
    if n <= 200:
        return 'low'
    elif n > 200 and n <=400:
        return 'medium'
    elif n > 400 and n <=600:
        return 'high'
    else:
        return 'very high'
    
df['installment'] = df['installment'].apply(lambda x: installment(x))

# %%
# ploting default rates across installment
plot_category('installment')

# %% [markdown]
# As we can see that the installent is very high due to heavy interest over default rates.

# %%
# categorizing annual income
def annual_income(n):
    if n <= 50000:
        return 'low'
    elif n > 50000 and n <=100000:
        return 'medium'
    elif n > 100000 and n <=150000:
        return 'high'
    else:
        return 'very high'

df['annual_inc'] = df['annual_inc'].apply(lambda x: annual_income(x))

# %%
# ploting annual income and default rate
plot_category('annual_inc')

# %% [markdown]
# See having higher income have higher rate.

# %%
# categorizing employment length to fresher, junior, senior, expert

df = df[~df['emp_length'].isnull()]

# binning the variable
def emp_length(n):
    if n <= 1:
        return 'fresher'
    elif n > 1 and n <=3:
        return 'junior'
    elif n > 3 and n <=7:
        return 'senior'
    else:
        return 'expert'

df['emp_length'] = df['emp_length'].apply(lambda x: emp_length(x))

# %%
# ploting emp_length and default rate
plot_category('emp_length')

# %% [markdown]
# See expert have higher rate and fresher and senior have the same

# %%
# ploting a countplot of purpose
plt.figure(figsize=(16, 6))
plt.xticks(rotation = 90)
plt.title("Number Of Loans Based On Purpose")
sns.countplot(x='purpose', data=df)
plt.show()

# %% [markdown]
#  See the top 4 types of loans based on debt_purpose: consolidation, credit card, home improvement and major purchase.
#  We cannot include other here.

# %%
# filtering the df for the 4 types of loans mentioned above
main_purposes = ["credit_card","debt_consolidation","home_improvement","major_purchase"]
df = df[df['purpose'].isin(main_purposes)]
df['purpose'].value_counts()
# Out:
# purpose
# debt_consolidation    17675
# credit_card            4899
# home_improvement       2785
# major_purchase         2080
# Name: count, dtype: int64

# %%
# plotting number of loans by major purpose
plt.figure(figsize=(12,8))
plt.title("number of loans by major purpose".title())
sns.countplot(x=df['purpose'])
plt.show()

# %% [markdown]
# As we can see the debt_consolidation is higher among all of them.

# %%
def plot_segmented(var):
    temp = df.groupby([var, 'purpose'])['default'].mean().unstack()
    temp.plot(kind='bar', figsize=(12, 6))
    plt.ylabel('Default Rate')
    plt.title(f'Default Rate by {var} segmented by Purpose')
    plt.xticks(rotation=45)
    plt.show()

# %%
# comparing the default rates across two types of categorical variables
# purpose of loan (constant) and another categorical variable (which changes)

plt.figure(figsize=(12, 8))
plt.title("Default Rates Across Term Segmented By Purpose")
sns.barplot(x='term', y="loan_status", hue='purpose', data=df)
plt.show()

# %%
# lets write a function which takes a categorical variable and plots the default rate
# segmented by purpose 

def plot_segmented(var):
    plt.figure(figsize=(14,10))
    sns.barplot(x=var, y='loan_status', hue='purpose', data=df)
    plt.title("Default Rates Across "+var.title() +" Semented By Purpose")
    plt.show()
    
# grade of loan
plot_segmented('grade')

# %%
#ploting home ownership
plot_segmented('home_ownership')

# %% [markdown]
# See dept_consolidation have high amoung 3 catagory, expect others

# %%
# ploting default rates across year segmented by purpose.
plot_segmented('year')

# %%
# ploting default rates across employee length segmented by purpose.
plot_segmented('emp_length')

# %%
# ploting default rates across loan amount segmented by purpose.
plot_segmented('loan_amnt')

# %%
# ploting default rates across interest rate segmented by purpose.
plot_segmented('int_rate')

# %% [markdown]
# As clearly seen that the high interest rate have high debt_consolidation

# %%
# ploting default rate across installment segmented by purpose.
plot_segmented('installment')

# %% [markdown]
# In low and medium category the home improvement and major purchase are almost same

# %%
# ploting default reates across debt to income ratio segmented by purpose.
plot_segmented('dti')

# %% [markdown]
# Here as well the dept_consolidation are higher .

# %%
# ploting default rates across annual income segmented by purpose.
plot_segmented('annual_inc')

# %% [markdown]
# As we can see debt consolidation loans have higher default rates.

# %% [markdown]
# As we can see in all the plot that the debt_consolidation is higher among all of them.
